# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import re
from IPython.display import display, Markdown

us_df = pd.read_csv("../data/US_youtube_trending_data.csv")
gb_df = pd.read_csv("../data/GB_youtube_trending_data.csv")

# %% [markdown]
# **For deep dive analysis of the number of subscribers, requires API, Here is the example:
# https://www.analyticssteps.com/blogs/how-extract-analyze-youtube-data-using-youtube-api
# I need duration of the video, refer to this:
# https://medium.com/geekculture/extracting-daily-youtube-trending-video-statistics-5de5f9fdc1b7
# **

# %%
#US first 10 records
display(us_df.head(10))
# Out:
#       video_id                                              title  \
# 0  3C66w5Z0ixs                 I ASKED HER TO BE MY GIRLFRIEND...
# 1  M9Pmf9AB4Mo  Apex Legends | Stories from the Outlands – “Th...
# 2  J78aPJ3VyNs  I left youtube for a month and THIS is what ha...
# 3  kXLn3HkpjaA  XXL 2020 Freshman Class Revealed - Official An...
# 4  VIUo6yapDbc  Ultimate DIY Home Movie Theater for The LaBran...
# 5  w-aidBdvZo8  I Haven't Been Honest About My Injury.. Here's...
# 6  uet14uf9NsE                           OUR FIRST FAMILY INTRO!!
# 7  ua4QMFQATco                                 CGP Grey was WRONG
# 8  SnsPZj91R7E  SURPRISING MY DAD WITH HIS DREAM TRUCK!! | Lou...
# 9  SsWHMAhshPQ  Ovi x Natanael Cano x Aleman x Big Soto - Veng...
#
#             publishedAt                 channelId    channelTitle  categoryId  \
# 0  2020-08-11T19:20:14Z  UCvtRTOMP2TqYqu51xNrqAzg        Brawadis          22
# 1  2020-08-11T17:00:10Z  UC0ZV6M2THA81QT9hrVWJG3A    Apex Legends          20
# 2  2020-08-11T16:34:06Z  UCYzPXprvl5Y-Sf0g4vX-m6g   jacksepticeye          24
# 3  2020-08-11T16:38:55Z  UCbg_UMjlHJg_19SZckaKajg             XXL          10
# 4  2020-08-11T15:10:05Z  UCDVPcEbVLQgLZX0Rt6jo34A        Mr. Kate          26
# 5  2020-08-11T20:00:04Z  UC5zJwsFtEs9WYe3A76p7xIA  Professor Live          24
# 6  2020-08-12T00:17:41Z  UCDSJCBYqL7VQrlXfhr1RtwA   Les Do Makeup          26
# 7  2020-08-11T17:15:11Z  UC2C_jShtL725hvbm1arSV9w        CGP Grey          27
# 8  2020-08-10T22:26:59Z  UCZDdF_p-L88NWVpzF0vjvMQ    Louie's Life          24
# 9  2020-08-11T23:00:10Z  UC648rgJOboZlgcDbW00vTSA  Rancho Humilde          10
#
#           trending_date                                               tags  \
# 0  2020-08-12T00:00:00Z  brawadis|prank|basketball|skits|ghost|funny vi...
# 1  2020-08-12T00:00:00Z  Apex Legends|Apex Legends characters|new Apex ...
# 2  2020-08-12T00:00:00Z  jacksepticeye|funny|funny meme|memes|jacksepti...
# 3  2020-08-12T00:00:00Z  xxl freshman|xxl freshmen|2020 xxl freshman|20...
# 4  2020-08-12T00:00:00Z  The LaBrant Family|DIY|Interior Design|Makeove...
# 5  2020-08-12T00:00:00Z  Professor injury|professor achilles|professor ...
# 6  2020-08-12T00:00:00Z                                             [None]
# 7  2020-08-12T00:00:00Z                   cgpgrey|education|hello internet
# 8  2020-08-12T00:00:00Z  surprising|dad|father|papa|with|dream|car|truc...
# 9  2020-08-12T00:00:00Z  Vengo De Nada|Aleman|Ovi|Big Soto|Trap|Ovi Nat...
#
#    view_count   likes  dislikes  comment_count  \
# 0     1514614  156908      5855          35313
# 1     2381688  146739      2794          16549
# 2     2038853  353787      2628          40221
# 3      496771   23251      1856           7647
# 4     1123889   45802       964           2196
# 5      949491   77487       746           7506
# 6      470446   47990       440           4558
# 7     1050143   89190       854           6455
# 8     1402687   95694      2158           6613
# 9      741028  113983      4373           5618
#
#                                    thumbnail_link  comments_disabled  \
# 0  https://i.ytimg.com/vi/3C66w5Z0ixs/default.jpg              False
# 1  https://i.ytimg.com/vi/M9Pmf9AB4Mo/default.jpg              False
# 2  https://i.ytimg.com/vi/J78aPJ3VyNs/default.jpg              False
# 3  https://i.ytimg.com/vi/kXLn3HkpjaA/default.jpg              False
# 4  https://i.ytimg.com/vi/VIUo6yapDbc/default.jpg              False
# 5  https://i.ytimg.com/vi/w-aidBdvZo8/default.jpg              False
# 6  https://i.ytimg.com/vi/uet14uf9NsE/default.jpg              False
# 7  https://i.ytimg.com/vi/ua4QMFQATco/default.jpg              False
# 8  https://i.ytimg.com/vi/SnsPZj91R7E/default.jpg              False
# 9  https://i.ytimg.com/vi/SsWHMAhshPQ/default.jpg              False
#
#    ratings_disabled                                        description
# 0             False  SUBSCRIBE to BRAWADIS ▶ http://bit.ly/Subscrib...
#
# 8  2020-08-12T00:00:00Z                                             [None]
# 9  2020-08-12T00:00:00Z  The LaBrant Family|DIY|Interior Design|Makeove...
#
#    view_count   likes  dislikes  comment_count  \
# 0     2038853  353790      2628          40228
# 1      236830   16423       209           1642
# 2     2381688  146739      2794          16549
# 3      613785   37567       669           2101
# 4      940036   87113      1860           7052
# 5     1050143   89192       855           6455
# 6    11308046  655449     33242         405146
# 7     1514614  156910      5856          35313
# 8      277506   27420       617           1268
# 9     1123889   45803       964           2198
#
#                                    thumbnail_link  comments_disabled  \
# 0  https://i.ytimg.com/vi/J78aPJ3VyNs/default.jpg              False
# 1  https://i.ytimg.com/vi/9nidKH8cM38/default.jpg              False
# 2  https://i.ytimg.com/vi/M9Pmf9AB4Mo/default.jpg              False
# 3  https://i.ytimg.com/vi/kgUV1MaD_M8/default.jpg              False
# 4  https://i.ytimg.com/vi/49Z6Mv4_WCA/default.jpg              False
# 5  https://i.ytimg.com/vi/ua4QMFQATco/default.jpg              False
# 6  https://i.ytimg.com/vi/x-KbnJ9fvJc/default.jpg              False
# 7  https://i.ytimg.com/vi/3C66w5Z0ixs/default.jpg              False
# 8  https://i.ytimg.com/vi/ZNfeMbO_AHo/default.jpg              False
# 9  https://i.ytimg.com/vi/VIUo6yapDbc/default.jpg              False
#
#    ratings_disabled                                        description
# 0             False  I left youtube for a month and this is what ha...
# 1             False  The first 1000 people to click the link will g...
# 2             False  While running her own modding shop, Ramya Pare...
# 3             False  Nines - Clout (Official Video)Listen to Clout ...
# 4             False  ssend love to my sponsor; for a super Limited ...
# 5             False  ‣ What Was TEKOI: https://www.youtube.com/watc...
# 6             False  Singer/Lyrics: Karan Aujla Feat Tania Music/ D...
# 7             False  SUBSCRIBE to BRAWADIS ▶ http://bit.ly/Subscrib...
# 8             False  Nowa wersja kultowego utworu z lat 90’.Posłuch...
# 9             False  Transforming The LaBrant Family's empty white ...

# %%
check_us_df = us_df.sort_values(by=['publishedAt'], ascending=False)
#2020-08-11T19:20:14Z
#us_df['publishedAt_date_time'] = pd.to_datetime(us_df['publishedAt'], format='%Y-%m-%dT%H%M%SZ')
#check_us_df['time_used_for_trending'] = us_df['trending_date']-us_df['publishedAt']
def find_number(text):
    num = re.findall(r'[0-9]+',text)
    return "".join(num)
check_us_df['publishedAt'] = check_us_df['publishedAt'].apply(lambda x: find_number(x))
check_us_df['publishedAt_date'] = check_us_df['publishedAt'].str.slice(0, 8)
check_us_df['publishedAt'] = pd.to_datetime(check_us_df['publishedAt'], format='%Y%m%d%H%M%S')
check_us_df['publishedAt_date'] = pd.to_datetime(check_us_df['publishedAt_date'], format='%Y%m%d')
check_us_df['trending_date'] = check_us_df['trending_date'].apply(lambda x: find_number(x))
check_us_df['trending_date'] = pd.to_datetime(check_us_df['trending_date'], format='%Y%m%d%H%M%S')
check_us_df['publishedAt_trending_diff'] = check_us_df['trending_date'] - check_us_df['publishedAt_date']
check_us_df = check_us_df.sort_values(by=['publishedAt_trending_diff'], ascending=True)
fast_trending_video = check_us_df[check_us_df['publishedAt_trending_diff']=='0 days']['video_id'].count()
print('number of video listed as trending video less than 1 day:', fast_trending_video)
print('number of video listed as trending video less than 1 day ratio:', (fast_trending_video/check_us_df.shape[0])*100, '%')
display(check_us_df.head(5))
# Out:
# number of video listed as trending video less than 1 day: 1109
# number of video listed as trending video less than 1 day ratio: 0.9763097428493455 %
#           video_id                                              title  \
# 9426   8e7K5M7J-3o  CELTICS at HEAT | FULL GAME HIGHLIGHTS | Septe...
# 42409  KRWxCRK7M1U  Matt Explains Why He Can't Be With Rachael | T...
# 33007  ab--iVhE51s   my experience GROWING UP CHUBBY (animated story)
# 27996  JeHUHuIRXHo         HIGHLIGHTS | Ryan Garcia vs. Luke Campbell
# 13633  i3HS54oAxbY  Apple MagSafe Charger - Unboxing and Everythin...
#
#               publishedAt                 channelId     channelTitle  \
# 9426  2020-09-28 02:08:59  UCWJ2lWNubArHWmf3FIHbfcQ              NBA
# 42409 2021-03-16 03:15:00  UChnGFN2LRHBq-0PM6dOaq5A  Bachelor Nation
# 33007 2021-01-28 05:21:34  UCAlxwHEm1bWWYoe5VCSQYEg       EroldStory
# 27996 2021-01-03 00:42:46  UCurvRE5fGcdUgCYWgh-BDsg      DAZN Boxing
# 13633 2020-10-19 02:09:15  UCiQMYozSSTkJ2twtZM1bG9w        zollotech
#
#        categoryId trending_date  \
# 9426           17    2020-09-28
# 42409          24    2021-03-16
# 33007           1    2021-01-28
# 27996          17    2021-01-03
# 13633          28    2020-10-19
#
#                                                     tags  view_count  likes  \
# 9426   NBA|G League|Basketball|game-0041900306|Basket...     1581107  18941
# 42409  bachelor nation|bachelorette abc|bachelor|bach...      146395   1155
# 33007                                             [None]      169114  38619
# 27996  dazn|boxing|highlights|full fight|ko|knockout|...     2236291  56022
# 13633  iPhone 12|iPhone 12 magsafe|MagSafe accessorie...      283359   9011
#
#        dislikes  comment_count  \
# 9426        725           5583
# 42409       764           1748
# 33007       135           5465
# 27996      1157           8959
# 13633       200           1093
#
#                                        thumbnail_link  comments_disabled  \
# 9426   https://i.ytimg.com/vi/8e7K5M7J-3o/default.jpg              False
# 42409  https://i.ytimg.com/vi/KRWxCRK7M1U/default.jpg              False
# 33007  https://i.ytimg.com/vi/ab--iVhE51s/default.jpg              False
# 27996  https://i.ytimg.com/vi/JeHUHuIRXHo/default.jpg              False
# 13633  https://i.ytimg.com/vi/i3HS54oAxbY/default.jpg              False
#
#        ratings_disabled                                        description  \
# 9426              False  CELTICS at HEAT | FULL GAME HIGHLIGHTS | Septe...
# 42409             False  Matt & Rachael reunite after their controversi...
# 33007             False  my store with shirts...that have CUTE ANIME GI...
# 27996             False  January 2nd, 2021 -- Ryan Garcia vs. Luke Camp...
# 13633             False  MagSafe from Apple is back for iPhone12, iPhon...
#
#       publishedAt_date publishedAt_trending_diff
# 9426        2020-09-28                    0 days
# 42409       2021-03-16                    0 days
# 33007       2021-01-28                    0 days
# 27996       2021-01-03                    0 days
# 13633       2020-10-19                    0 days

# %%
num_day_to_trending_df =  check_us_df[['video_id','publishedAt_trending_diff']].groupby('publishedAt_trending_diff', as_index=False).count()
display(num_day_to_trending_df)
num_day_to_trending_graph = num_day_to_trending_df.plot.bar(x='publishedAt_trending_diff', y='video_id', figsize=(15,5), title='Number of day for video to be listed as trending', alpha=0.5)
# Out:
#    publishedAt_trending_diff  video_id
# 0                     0 days      1109
# 1                     1 days     13105
# 2                     2 days     17900
# 3                     3 days     18782
# 4                     4 days     19319
# 5                     5 days     17853
# 6                     6 days     13293
# 7                     7 days      7135
# 8                     8 days      2814
# 9                     9 days      1075
# 10                   10 days       445
# 11                   11 days       206
# 12                   12 days        99
# 13                   13 days        60
# 14                   14 days        44
# 15                   15 days        41
# 16                   16 days        38
# 17                   17 days        31
# 18                   18 days        26
# 19                   19 days        20
# 20                   20 days        21
# 21                   21 days        20
# 22                   22 days        15
# 23                   23 days        15
# 24                   24 days        12
# 25                   25 days        14
# 26                   26 days        13
# 27                   27 days        15
# 28                   28 days        14
# 29                   29 days        15
# 30                   30 days        13
# 31                   31 days        10
# 32                   32 days         4
# 33                   33 days         4
# 34                   34 days         4
# 35                   35 days         1
# 36                   36 days         5
# 37                   37 days         1

# %%
def search_words(text):
    result = re.findall(r'\b[^\d\W]+\b', text)
    result = list(map(lambda x: x.lower(), result))
    filter_result = []
    for i in result:
        if "_" not in i:
            filter_result.append(i)
    return filter_result
check_us_df['title_keywords']=check_us_df['title'].apply(lambda x : search_words(x))
display(check_us_df)
# Out:
#           video_id                                              title  \
# 9426   8e7K5M7J-3o  CELTICS at HEAT | FULL GAME HIGHLIGHTS | Septe...
# 42409  KRWxCRK7M1U  Matt Explains Why He Can't Be With Rachael | T...
# 33007  ab--iVhE51s   my experience GROWING UP CHUBBY (animated story)
# 27996  JeHUHuIRXHo         HIGHLIGHTS | Ryan Garcia vs. Luke Campbell
# 13633  i3HS54oAxbY  Apple MagSafe Charger - Unboxing and Everythin...
# ...            ...                                                ...
# 73564  hdmx71UjBXs                Turn into orbeez - Tutorial #Shorts
# 74390  vrRfBmMWpLY  Golden Buzzer: 9-Year-Old Victory Brinker Make...
# 38577  wY6UyatwVTA  India claim stunning series win, end Australia...
# 38377  wY6UyatwVTA  India claim stunning series win, end Australia...
# 96185  nLxmuh6wCVY  Highlights: Manchester United 0-5 Liverpool | ...
#
#               publishedAt                 channelId          channelTitle  \
# 9426  2020-09-28 02:08:59  UCWJ2lWNubArHWmf3FIHbfcQ                   NBA
# 42409 2021-03-16 03:15:00  UChnGFN2LRHBq-0PM6dOaq5A       Bachelor Nation
# 33007 2021-01-28 05:21:34  UCAlxwHEm1bWWYoe5VCSQYEg            EroldStory
# 27996 2021-01-03 00:42:46  UCurvRE5fGcdUgCYWgh-BDsg           DAZN Boxing
# 13633 2020-10-19 02:09:15  UCiQMYozSSTkJ2twtZM1bG9w             zollotech
# ...                   ...                       ...                   ...
# 73564 2021-07-03 04:04:57  UCt8z2S30Wl-GQEluFVM8NUw                FFUNTV
# 74390             False  For the first time EVER, the judges and host a...
# 38577             False  Rishabh Pant was the hero as an injury-ravaged...
# 38377             False  Rishabh Pant was the hero as an injury-ravaged...
# 96185             False  Watch highlights of Liverpool's sensational 5-...
#
#       publishedAt_date publishedAt_trending_diff  \
# 9426        2020-09-28                    0 days
# 42409       2021-03-16                    0 days
# 33007       2021-01-28                    0 days
# 27996       2021-01-03                    0 days
# 13633       2020-10-19                    0 days
# ...                ...                       ...
# 73564       2021-07-03                   36 days
# 74390       2021-07-07                   36 days
# 38577       2021-01-19                   36 days
# 38377       2021-01-19                   36 days
# 96185       2021-10-24                   37 days
#
#                                           title_keywords
# 9426   [celtics, at, heat, full, game, highlights, se...
# 42409  [matt, explains, why, he, can, t, be, with, ra...
# 33007  [my, experience, growing, up, chubby, animated...
# 27996     [highlights, ryan, garcia, vs, luke, campbell]
# 13633  [apple, magsafe, charger, unboxing, and, every...
# ...                                                  ...
# 73564             [turn, into, orbeez, tutorial, shorts]
# 74390  [golden, buzzer, year, old, victory, brinker, ...
# 38577  [india, claim, stunning, series, win, end, aus...
# 38377  [india, claim, stunning, series, win, end, aus...
# 96185  [highlights, manchester, united, liverpool, sa...
#
# [113591 rows x 19 columns]

# %%
title_keyword_list = []
for wordlist in check_us_df['title_keywords'].tolist():
    for word in wordlist:
        title_keyword_list.append(word)


unique_title_keys = set(title_keyword_list)
print('total number of keywords:', len(title_keyword_list))
print('total number of unique keywords:', len(unique_title_keys))
title_key_word_count_list = []
for i in title_keyword_list:
    title_key_word_count_list.append(1)
title_keyword_df = pd.DataFrame(data=title_keyword_list, columns=['title_keyword'])
title_keyword_df['count'] = title_key_word_count_list
title_keyword_count_df = title_keyword_df[['title_keyword','count']].groupby('title_keyword', as_index=False).count()
title_keyword_count_df = title_keyword_count_df.sort_values(by='count', ascending=False)
display(title_keyword_count_df.head(50))
# Out:
# total number of keywords: 903627
# total number of unique keywords: 17425
#       title_keyword  count
# 15104           the  26454
# 10571      official  14493
# 16194         video  12842
# 0                 a  12038
# 15321            to  11374
# 7282             in  11356
# 12930             s  11316
# 7158              i  11234
# 10558            of   7900
# 16326            vs   6205
# 10024            my   6125
# 493             and   6027
# 10638            on   5916
# 16709          with   5715
# 9602      minecraft   5134
# 16971           you   5034
# 7522             is   4747
# 9996          music   4696
# 15484       trailer   4544
# 6812     highlights   4448
# 5597            for   4281
# 13557        shorts   3955
# 10252           new   3822
# 824              at   3452
# 5859           game   3166
# 5765             ft   3118
# 7547             it   2930
# 7041            how   2750
# 15150          this   2710
# 14814             t   2620
# 5438          first   2609
# 16488            we   2526
# 5743           from   2460
# 16563          what   2304
# 2050            but   2247
# 9340             me   2169
# 16857             x   2150
# 16005            us   2125
# 13231        season   2119
# 8625            lil   2048
# 16782         world   1991
# 5256           feat   1947
# 2179            can   1827
# 3658            day   1797
# 8693           live   1792
# 8960              m   1707
# 16981          your   1679
# 5780           full   1666
# 2071             by   1665
# 8596           life   1664
